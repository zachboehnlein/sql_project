# %%
pip install https://github.com/pdftables/python-pdftables-api/archive/master.tar.gz
# Out:
# ...
#   Using cached https://github.com/pdftables/python-pdftables-api/archive/master.tar.gz
# ...
#   Created wheel for pdftables-api: filename=pdftables_api-1.1.0-cp37-none-any.whl size=5891 sha256=99a38075068cfce8d02099fa41f1bfbd78a56415441d20ce99175db46303c639
#   Stored in directory: C:\Users\zachb\AppData\Local\Temp\pip-ephem-wheel-cache-nbbotjvr\wheels\30\c9\11\f8f1015a0cdc2f54dcd3ea475c014b7333ec7699b9cfec7873
# Successfully built pdftables-api
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdftables_api

c = pdftables_api.Client('kxe6xky5xoev')
c.csv('state_divorce_rates_90_95_99-16.pdf', 'state_divorce_rates_90_95_99-16.csv')

# %%
import pandas as pd

# %%
df =pd.read_csv('state_divorce_rates_90_95_99-16.csv')
df.head()
df.dropna()
headers = df.iloc[3]
new_df  = pd.DataFrame(df.values[4:], columns=headers)
final_df = new_df.drop(new_df.index[[51, 52, 53, 54]])
final_df
# Out:
# 3                  State 2016 2015 2014 2013 2012 2011 2010 2009 2008  ...  \
# 0                Alabama  3.8  3.9  3.8  3.7  3.6  4.3  4.4  4.4  4.3  ...
# 1                 Alaska  3.9  4.1  4.0  4.5  4.5  4.8  4.7  4.4  4.4  ...
# 2                Arizona  3.4  3.6  3.9  3.9  4.3  3.9  3.5  3.6  3.8  ...
# 3               Arkansas  3.9  4.8  4.8  5.0  5.3  5.3  5.7  5.7  5.5  ...
# 4             California  ---  ---  ---  ---  ---  ---  ---  ---  ---  ...
# 5               Colorado  3.6  3.7  3.9  4.1  4.3  4.4  4.3  4.3  4.3  ...
# 6            Connecticut  3.2  3.1  2.6  2.8  2.7  3.1  2.9  3.0  3.4  ...
# 7               Delaware  3.1  3.1  3.3  3.4  3.5  3.6  3.5  3.6  3.5  ...
# 8   District of Columbia  2.7  2.8  2.6  2.8  2.9  2.9  2.8  2.7  2.7  ...
# 9                Florida  3.9  4.0  4.0  4.1  4.2  4.5  4.4  4.2  4.3  ...
# 10               Georgia  ---  ---  ---  ---  ---  ---  ---  ---  ---  ...
# ...

# %%
from sqlalchemy import create_engine 
final_df.to_csv('divorce.csv', index = False)

# %%
engine = create_engine('mysql+mysqldb://admin:sql_2020@lmu-sql.cooejkcwn3hp.us-east-2.rds.amazonaws.com/sql_project')

# %%
final_df.to_sql('divorce_rates', engine, if_exists='replace')
